# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# SQLAlchemy
from sqlalchemy import create_engine

# Path to sqlite
database_path = "../Resources/Covid_data.sqlite"

# %%
# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM Covid_data")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
# ...

# %%
unemployment = pd.read_csv('Resources/unemployment_rate.csv')
unemployment.head()
# Out:
#   Unemployment Rate (Seasonally Adjusted)  United States  Arizona  \
# 0                              June 1999             NaN      NaN
# 1                              July 1999             NaN      NaN
# 2                            August 1999             NaN      NaN
# 3                         September 1999             NaN      NaN
# 4                           October 1999             NaN      NaN
#
#    Phoenix-Mesa-Glendale MSA (Maricopa + Pinal Co.)  Tucson MSA (Pima Co.)
# 0                                          3.108629               2.776268
# 1                                          3.041066               3.608514
# 2                                          2.930926               3.235266
# 3                                          2.966964               3.267238
# 4                                          3.029771               3.497081

# %%
unemployment = unemployment.dropna(how="any")
unemployment
# Out:
#     Unemployment Rate (Seasonally Adjusted)  United States  Arizona  \
# 67                            January 2005             5.3      4.8
# 68                           February 2005             5.4      4.8
# 69                              March 2005             5.2      4.8
# 70                              April 2005             5.2      4.8
# 71                                May 2005             5.1      4.7
# ..                                      ...            ...      ...
# 245                          November 2019             3.5      4.5
# 246                          December 2019             3.5      4.5
# 247                           January 2020             3.6      4.5
# 248                          February 2020             3.5      4.5
# 249                             March 2020             4.4      5.5
#
#      Phoenix-Mesa-Glendale MSA (Maricopa + Pinal Co.)  Tucson MSA (Pima Co.)
# ...

# %%
unemployment.describe()
# Out:
#        United States     Arizona  \
# count     183.000000  183.000000
# mean        6.067760    6.455738
# std         1.996453    2.148922
# min         3.500000    3.600000
# 25%         4.600000    4.700000
# 50%         5.100000    5.600000
# 75%         7.800000    8.000000
# max        10.000000   10.900000
#
#        Phoenix-Mesa-Glendale MSA (Maricopa + Pinal Co.)  Tucson MSA (Pima Co.)
# count                                        183.000000             183.000000
# mean                                           5.733089               5.893638
# std                                            2.069960               1.846928
# min                                            2.970907               3.259873
# 25%                                            4.112566               4.407450
# 50%                                            4.917818               5.224701
# 75%                                            6.998882               7.041569
# ...

# %%
x = unemployment[['Phoenix-Mesa-Glendale MSA (Maricopa + Pinal Co.)']]
y = unemployment["Unemployment Rate (Seasonally Adjusted)"].values.reshape(-1, 1)
print(x.shape, y.shape)
# Out:
# (183, 1) (183, 1)

# %%
 # Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)
### END SOLUTION

# %%
 from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
x_scaler = StandardScaler().fit(x_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-618f106f0ca2> in <module>
#       5 ### BEGIN SOLUTION
#       6 x_scaler = StandardScaler().fit(x_train)
# ----> 7 y_scaler = StandardScaler().fit(y_train)
#       8 ### END SOLUTION
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     661         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     662                         estimator=self, dtype=FLOAT_DTYPES,
# --> 663                         force_all_finite='allow-nan')
#     664
# ...
